# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 16, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

tsla_training_complete = pd.read_csv(r'./data/TSLA_5Y.csv')
tsla_training_processed_complete = tsla_training_complete.iloc[:, 1:2].values
tsla_training_scaled_complete = scaler.fit_transform(tsla_training_processed_complete)

# %%
# plt.plot(time, sin, label='sine (with noise)');
# plt.legend();

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.DataFrame(tsla_training_scaled_complete, columns=['open'])
df.head(11)

df_original = pd.DataFrame(tsla_training_processed_complete, columns=['open'])
df_original.head(11)
# Out:
#           open
# 0   194.389999
# 1   188.460007
# 2   191.149994
# 3   193.750000
# 4   188.949997
# 5   192.000000
# 6   195.429993
# 7   194.960007
# 8   202.000000
# 9   197.449997
# 10  198.500000

# %%
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size

train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(train), len(test))

train_original, test_original = df_original.iloc[0:train_size], df_original.iloc[train_size:len(df_original)]

test.head()
# Out:
# 1007 252
#           open
# 1007  0.172291
# 1008  0.180752
# 1009  0.184554
# 1010  0.181239
# 1011  0.192184

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 60

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train.open, time_steps)
X_test, y_test = create_dataset(test, test.open, time_steps)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (947, 60, 1) (947,)
# (192, 60, 1) (192,)

# %% [markdown]
# # Modeling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

model = keras.Sequential()
# model.add(keras.layers.LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(keras.layers.Dense(1))

model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

# model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(0.001))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# ## Training

# %%
history = model.fit(
    X_train, y_train, 
    epochs=100, 
    batch_size=32, 
    validation_split=0.1, 
    verbose=1
)
# Out:
# Train on 852 samples, validate on 95 samples
# Epoch 1/100
# 852/852 [==============================] - 18s 22ms/sample - loss: 0.0057 - val_loss: 0.0028
# Epoch 2/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 0.0017 - val_loss: 0.0015
# Epoch 3/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 0.0011 - val_loss: 0.0013
# Epoch 4/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 0.0011 - val_loss: 0.0014
# Epoch 5/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 0.0010 - val_loss: 0.0015
# Epoch 6/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 0.0011 - val_loss: 0.0014
# Epoch 7/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 0.0010 - val_loss: 0.0016
# Epoch 8/100
# 852/852 [==============================] - 9s 11ms/sample - loss: 9.6632e-04 - val_loss: 0.0012
# Epoch 9/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 9.0262e-04 - val_loss: 0.0012
# Epoch 10/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 8.5044e-04 - val_loss: 0.0011
# Epoch 11/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 8.7733e-04 - val_loss: 0.0011
# Epoch 12/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 8.5993e-04 - val_loss: 0.0011
# Epoch 13/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 9.5069e-04 - val_loss: 0.0010
# Epoch 14/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 7.2583e-04 - val_loss: 0.0015
# Epoch 15/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 8.0285e-04 - val_loss: 0.0011
# Epoch 16/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 6.9173e-04 - val_loss: 0.0011
# Epoch 17/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 7.9435e-04 - val_loss: 0.0011
# Epoch 18/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 7.2240e-04 - val_loss: 0.0013
# Epoch 19/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 6.5943e-04 - val_loss: 8.9243e-04
# Epoch 20/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 6.3122e-04 - val_loss: 9.9404e-04
# Epoch 21/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 6.0544e-04 - val_loss: 0.0011
# Epoch 22/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 6.0338e-04 - val_loss: 9.5176e-04
# Epoch 23/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 6.0449e-04 - val_loss: 8.7601e-04
# Epoch 24/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 6.0469e-04 - val_loss: 8.2964e-04
# Epoch 25/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 5.5270e-04 - val_loss: 9.0525e-04
# Epoch 26/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 5.4716e-04 - val_loss: 7.3914e-04
# Epoch 27/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 5.5746e-04 - val_loss: 8.1468e-04
# Epoch 28/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 5.0121e-04 - val_loss: 8.4466e-04
# Epoch 29/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 5.2960e-04 - val_loss: 7.0041e-04
# Epoch 30/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.8086e-04 - val_loss: 6.7207e-04
# Epoch 31/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.4689e-04 - val_loss: 6.8519e-04
# Epoch 32/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.7343e-04 - val_loss: 6.3121e-04
# Epoch 33/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.9279e-04 - val_loss: 6.4904e-04
# Epoch 34/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.8676e-04 - val_loss: 7.8227e-04
# Epoch 35/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.3830e-04 - val_loss: 5.6888e-04
# Epoch 36/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 4.5648e-04 - val_loss: 5.9654e-04
# Epoch 37/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.3303e-04 - val_loss: 5.3257e-04
# Epoch 38/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.2100e-04 - val_loss: 5.8609e-04
# Epoch 39/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 4.1788e-04 - val_loss: 5.0700e-04
# Epoch 40/100
# 852/852 [==============================] - 7s 9ms/sample - loss: 4.1530e-04 - val_loss: 4.8404e-04
# Epoch 41/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 3.7834e-04 - val_loss: 6.4437e-04
# Epoch 42/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 4.3417e-04 - val_loss: 4.6795e-04
# Epoch 43/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 3.8827e-04 - val_loss: 5.2225e-04
# Epoch 44/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 3.5558e-04 - val_loss: 4.4483e-04
# Epoch 45/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 3.6938e-04 - val_loss: 4.4652e-04
# Epoch 46/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 3.6183e-04 - val_loss: 4.3184e-04
# Epoch 47/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.6021e-04 - val_loss: 4.7525e-04
# Epoch 48/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.3879e-04 - val_loss: 4.1382e-04
# Epoch 49/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.8344e-04 - val_loss: 4.0313e-04
# Epoch 50/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.7415e-04 - val_loss: 4.2376e-04
# Epoch 51/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 3.0649e-04 - val_loss: 4.0714e-04
# Epoch 52/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 3.5659e-04 - val_loss: 3.9177e-04
# Epoch 53/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.9993e-04 - val_loss: 4.0638e-04
# Epoch 54/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.3252e-04 - val_loss: 3.9421e-04
# Epoch 55/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.9188e-04 - val_loss: 3.7860e-04
# Epoch 56/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.9995e-04 - val_loss: 3.9606e-04
# Epoch 57/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.9970e-04 - val_loss: 3.6330e-04
# Epoch 58/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.2820e-04 - val_loss: 4.2553e-04
# Epoch 59/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.0253e-04 - val_loss: 3.7849e-04
# Epoch 60/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 2.8601e-04 - val_loss: 3.9937e-04
# Epoch 61/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8874e-04 - val_loss: 3.6942e-04
# Epoch 62/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8842e-04 - val_loss: 3.6729e-04
# Epoch 63/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.9493e-04 - val_loss: 3.3718e-04
# Epoch 64/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8858e-04 - val_loss: 3.5995e-04
# Epoch 65/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8012e-04 - val_loss: 3.5829e-04
# Epoch 66/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8843e-04 - val_loss: 3.3508e-04
# Epoch 67/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.6323e-04 - val_loss: 3.6363e-04
# Epoch 68/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.4431e-04 - val_loss: 3.3861e-04
# Epoch 69/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8186e-04 - val_loss: 3.1870e-04
# Epoch 70/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.4511e-04 - val_loss: 3.2373e-04
# Epoch 71/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.6612e-04 - val_loss: 3.2557e-04
# Epoch 72/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.6747e-04 - val_loss: 3.6720e-04
# Epoch 73/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.8454e-04 - val_loss: 3.1095e-04
# Epoch 74/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 2.6638e-04 - val_loss: 3.3130e-04
# Epoch 75/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 2.6764e-04 - val_loss: 3.0389e-04
# Epoch 76/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 2.6479e-04 - val_loss: 3.0079e-04
# Epoch 77/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 3.1070e-04 - val_loss: 2.9499e-04
# Epoch 78/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 2.6157e-04 - val_loss: 3.4432e-04
# Epoch 79/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.4714e-04 - val_loss: 3.1994e-04
# Epoch 80/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.3273e-04 - val_loss: 2.8823e-04
# Epoch 81/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.3063e-04 - val_loss: 2.9256e-04
# Epoch 82/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.1381e-04 - val_loss: 3.0024e-04
# Epoch 83/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.2837e-04 - val_loss: 2.7375e-04
# Epoch 84/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.3163e-04 - val_loss: 2.7189e-04
# Epoch 85/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.4053e-04 - val_loss: 3.0841e-04
# Epoch 86/100
# 852/852 [==============================] - 8s 9ms/sample - loss: 2.4652e-04 - val_loss: 2.5955e-04
# Epoch 87/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.0619e-04 - val_loss: 3.3594e-04
# Epoch 88/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.1788e-04 - val_loss: 2.9055e-04
# Epoch 89/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.2404e-04 - val_loss: 2.7452e-04
# Epoch 90/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.0998e-04 - val_loss: 2.5590e-04
# Epoch 91/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.2763e-04 - val_loss: 3.6404e-04
# Epoch 92/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.3337e-04 - val_loss: 3.0202e-04
# Epoch 93/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.2713e-04 - val_loss: 2.4683e-04
# Epoch 94/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.4166e-04 - val_loss: 2.8383e-04
# Epoch 95/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.0146e-04 - val_loss: 2.4027e-04
# Epoch 96/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 2.1404e-04 - val_loss: 2.4339e-04
# Epoch 97/100
# 852/852 [==============================] - 9s 10ms/sample - loss: 1.9817e-04 - val_loss: 2.3202e-04
# Epoch 98/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.1982e-04 - val_loss: 2.6189e-04
# Epoch 99/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.1324e-04 - val_loss: 2.4740e-04
# Epoch 100/100
# 852/852 [==============================] - 8s 10ms/sample - loss: 2.2954e-04 - val_loss: 3.0840e-04

# %% [markdown]
# ## Evaluation

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
y_pred = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred)

y_test = np.reshape(y_test, (y_test.shape[0], 1))
y_test.shape

y_train = np.reshape(y_train, (y_train.shape[0], 1))
y_train.shape

y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# %%
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.plot(y_test, marker='.', label="true")
plt.plot(y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();
